# %% [markdown]
# # **Limpieza - Delitos Ambientales**
# ---
# **Elaborado con base en**
# * [DELITOS CONTRA EL MEDIO AMBIENTE | Datos Abiertos Colombia](https://www.datos.gov.co/Seguridad-y-Defensa/DELITOS-CONTRA-EL-MEDIO-AMBIENTE/9zck-qfvc/about_data)

# %% [markdown]
# ### ***Importar librerías***

# %%
import requests
import pandas as pd
import io
import csv
from datetime import datetime

# %% [markdown]
# ### ***Recibir los datos provenientes de la API***

# %%
url = 'https://www.datos.gov.co/resource/9zck-qfvc.csv?$query=SELECT%0A%20%20%60fecha_hecho%60%2C%0A%20%20%60cod_depto%60%2C%0A%20%20%60departamento%60%2C%0A%20%20%60cod_muni%60%2C%0A%20%20%60municipio%60%2C%0A%20%20%60descripcion_conducta%60%2C%0A%20%20%60zona%60%2C%0A%20%20%60cantidad%60%0AWHERE%0A%20%20caseless_one_of(%0A%20%20%20%20%60departamento%60%2C%0A%20%20%20%20%22VALLE%20DEL%20CAUCA%22%2C%0A%20%20%20%20%22CAUCA%22%2C%0A%20%20%20%20%22CHOCO%22%2C%0A%20%20%20%20%22NARI%C3%91O%22%2C%0A%20%20%20%20%22CHOC%C3%93%22%2C%0A%20%20%20%20%22NARINO%22%0A%20%20)%20LIMIT%2035000000%20OFFSET%200'

response = requests.get(url)

data = io.StringIO(response.text)
dialect = csv.Sniffer().sniff(data.read(1024))

data.seek(0)
# Out:
# 0

# %% [markdown]
# ### ***Procesar los datos mediante Pandas***

# %%
df = pd.read_csv(data, delimiter=dialect.delimiter)
df.head(-1)
#print(len(df))
# Out:
#                   fecha_hecho  cod_depto     departamento  cod_muni  \
# 0     2024-06-13T00:00:00.000         19            CAUCA     19001
# 1     2024-04-25T00:00:00.000         19            CAUCA     19698
# 2     2024-04-23T00:00:00.000         19            CAUCA     19532
# 3     2024-04-03T00:00:00.000         19            CAUCA     19001
# 4     2024-04-03T00:00:00.000         19            CAUCA     19698
# ...                       ...        ...              ...       ...
# 6133  2003-02-23T00:00:00.000         76  VALLE DEL CAUCA     76233
# 6134  2003-02-22T00:00:00.000         76  VALLE DEL CAUCA     76318
# 6135  2003-02-06T00:00:00.000         76  VALLE DEL CAUCA     76736
# 6136  2003-01-28T00:00:00.000         76  VALLE DEL CAUCA     76147
# 6137  2003-01-25T00:00:00.000         76  VALLE DEL CAUCA     76147
#
#                    municipio  \
# 0                    POPAYAN
# 1     SANTANDER DE QUILICHAO
# 2                      PATIA
# 3                    POPAYAN
# 4     SANTANDER DE QUILICHAO
# ...                      ...
# 6133                   DAGUA
# 6134                 GUACARI
# 6135                 SEVILLA
# 6136                 CARTAGO
# 6137                 CARTAGO
#
#                                    descripcion_conducta    zona  cantidad
# 0     ARTICULO 333. DAÑOS EN LOS RECURSOS NATURALES ...   RURAL         1
# 1     ARTICULO 336. INVASION DE AREAS DE ESPECIAL IM...   RURAL         1
# 2     ARTICULO 332. EXPLOTACION ILICITA DE YACIMIENT...   RURAL         1
# 3     ARTICULO 328. APROVECHAMIENTO ILICITO DE LOS R...   RURAL         1
# 4     ARTICULO 328. APROVECHAMIENTO ILICITO DE LOS R...   RURAL         1
# ...                                                 ...     ...       ...
# 6133      ARTICULO 331. DAÑOS EN LOS RECURSOS NATURALES   RURAL         1
# 6134      ARTICULO 331. DAÑOS EN LOS RECURSOS NATURALES   RURAL         1
# 6135      ARTICULO 331. DAÑOS EN LOS RECURSOS NATURALES   RURAL         1
# 6136      ARTICULO 331. DAÑOS EN LOS RECURSOS NATURALES   RURAL         1
# 6137      ARTICULO 331. DAÑOS EN LOS RECURSOS NATURALES  URBANA         1
#
# [6138 rows x 8 columns]

# %% [markdown]
# ### ***Limpiar datos vacíos***

# %%
df = df.dropna()
df = df.drop_duplicates()

df
# Out:
#                   fecha_hecho  cod_depto     departamento  cod_muni  \
# 0     2024-06-13T00:00:00.000         19            CAUCA     19001
# 1     2024-04-25T00:00:00.000         19            CAUCA     19698
# 2     2024-04-23T00:00:00.000         19            CAUCA     19532
# 3     2024-04-03T00:00:00.000         19            CAUCA     19001
# 4     2024-04-03T00:00:00.000         19            CAUCA     19698
# ...                       ...        ...              ...       ...
# 6134  2003-02-22T00:00:00.000         76  VALLE DEL CAUCA     76318
# 6135  2003-02-06T00:00:00.000         76  VALLE DEL CAUCA     76736
# 6136  2003-01-28T00:00:00.000         76  VALLE DEL CAUCA     76147
# 6137  2003-01-25T00:00:00.000         76  VALLE DEL CAUCA     76147
# 6138  2003-01-20T00:00:00.000         76  VALLE DEL CAUCA     76147
#
#                    municipio  \
# 0                    POPAYAN
# 1     SANTANDER DE QUILICHAO
# 2                      PATIA
# 3                    POPAYAN
# 4     SANTANDER DE QUILICHAO
# ...                      ...
# 6134                 GUACARI
# 6135                 SEVILLA
# 6136                 CARTAGO
# 6137                 CARTAGO
# 6138                 CARTAGO
#
#                                    descripcion_conducta    zona  cantidad
# 0     ARTICULO 333. DAÑOS EN LOS RECURSOS NATURALES ...   RURAL         1
# 1     ARTICULO 336. INVASION DE AREAS DE ESPECIAL IM...   RURAL         1
# 2     ARTICULO 332. EXPLOTACION ILICITA DE YACIMIENT...   RURAL         1
# 3     ARTICULO 328. APROVECHAMIENTO ILICITO DE LOS R...   RURAL         1
# 4     ARTICULO 328. APROVECHAMIENTO ILICITO DE LOS R...   RURAL         1
# ...                                                 ...     ...       ...
# 6134      ARTICULO 331. DAÑOS EN LOS RECURSOS NATURALES   RURAL         1
# 6135      ARTICULO 331. DAÑOS EN LOS RECURSOS NATURALES   RURAL         1
# 6136      ARTICULO 331. DAÑOS EN LOS RECURSOS NATURALES   RURAL         1
# 6137      ARTICULO 331. DAÑOS EN LOS RECURSOS NATURALES  URBANA         1
# 6138      ARTICULO 331. DAÑOS EN LOS RECURSOS NATURALES   RURAL         1
#
# [6139 rows x 8 columns]

# %% [markdown]
# ### ***Limpieza de columnas***

# %%
df = df.drop(['cod_depto', 'cod_muni'], axis=1)

df['departamento'] = df['departamento'].replace({'NARINO': 'NARIÑO', 'CHOCO': 'CHOCÓ'})

# %%
# print(df['zona'].unique())
# print(df['departamento'].unique())
# print(df['municipio'].unique())
# print(df['descripcion_conducta'].unique())

# %% [markdown]
# ### ***Arreglar el formato de la fecha***

# %%
df['fecha_hecho'] = df['fecha_hecho'].apply(lambda x: datetime.strptime(x, "%Y-%m-%dT%H:%M:%S.%f").date())

# Crea nuevas columnas para el año, mes y día
df['año'] = df['fecha_hecho'].apply(lambda x: x.year)
df['mes'] = df['fecha_hecho'].apply(lambda x: x.month)
df['mesOrden'] = df['fecha_hecho'].apply(lambda x: x.month)
df['día'] = df['fecha_hecho'].apply(lambda x: x.day)

df = df.reset_index(drop=True)

df = df.drop(['fecha_hecho'], axis=1)

#Para quitar los espacios en blanco al principio y al final de cada celda:
df = df.applymap(lambda x: x.strip() if isinstance(x, str) else x)

df['año'] = df['año'].astype(int)
df = df[df['año'] >= 1900]
# Out:
# C:\Users\marti\AppData\Local\Temp\ipykernel_13364\880750760.py:11: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: x.strip() if isinstance(x, str) else x)

# %%
# print(df['año'].unique())
# df.head(-1)

# %% [markdown]
# #### ***Mapear los meses a su nombre y reorganizar el orden de las columnas***

# %%
# Mapear los meses a su nombre
meses_map = {
    1: 'Enero',
    2: 'Febrero',
    3: 'Marzo',
    4: 'Abril',
    5: 'Mayo',
    6: 'Junio',
    7: 'Julio',
    8: 'Agosto',
    9: 'Septiembre',
    10: 'Octubre',
    11: 'Noviembre',
    12: 'Diciembre'
}

df['mes'] = df['mes'].map(meses_map)

# %%
df.head(-1)
# Out:
#          departamento               municipio  \
# 0               CAUCA                 POPAYAN
# 1               CAUCA  SANTANDER DE QUILICHAO
# 2               CAUCA                   PATIA
# 3               CAUCA                 POPAYAN
# 4               CAUCA  SANTANDER DE QUILICHAO
# ...               ...                     ...
# 6133  VALLE DEL CAUCA                   DAGUA
# 6134  VALLE DEL CAUCA                 GUACARI
# 6135  VALLE DEL CAUCA                 SEVILLA
# 6136  VALLE DEL CAUCA                 CARTAGO
# 6137  VALLE DEL CAUCA                 CARTAGO
#
#                                    descripcion_conducta    zona  cantidad  \
# 0     ARTICULO 333. DAÑOS EN LOS RECURSOS NATURALES ...   RURAL         1
# 1     ARTICULO 336. INVASION DE AREAS DE ESPECIAL IM...   RURAL         1
# 2     ARTICULO 332. EXPLOTACION ILICITA DE YACIMIENT...   RURAL         1
# 3     ARTICULO 328. APROVECHAMIENTO ILICITO DE LOS R...   RURAL         1
# 4     ARTICULO 328. APROVECHAMIENTO ILICITO DE LOS R...   RURAL         1
# ...                                                 ...     ...       ...
# 6133      ARTICULO 331. DAÑOS EN LOS RECURSOS NATURALES   RURAL         1
# 6134      ARTICULO 331. DAÑOS EN LOS RECURSOS NATURALES   RURAL         1
# 6135      ARTICULO 331. DAÑOS EN LOS RECURSOS NATURALES   RURAL         1
# 6136      ARTICULO 331. DAÑOS EN LOS RECURSOS NATURALES   RURAL         1
# 6137      ARTICULO 331. DAÑOS EN LOS RECURSOS NATURALES  URBANA         1
#
#        año      mes  mesOrden  día
# 0     2024    Junio         6   13
# 1     2024    Abril         4   25
# 2     2024    Abril         4   23
# 3     2024    Abril         4    3
# 4     2024    Abril         4    3
# ...    ...      ...       ...  ...
# 6133  2003  Febrero         2   23
# 6134  2003  Febrero         2   22
# 6135  2003  Febrero         2    6
# 6136  2003    Enero         1   28
# 6137  2003    Enero         1   25
#
# [6138 rows x 9 columns]

# %% [markdown]
# #### ***Exportar el dataframe como CSV***

# %%
df.to_csv('delitosAmbientalesAPI.csv', index=False)
